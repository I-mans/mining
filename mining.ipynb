# %% [markdown]
# CEK GPU

# %%
# !nvidia-smi -L

# %% [markdown]
# CEK GPU

# %%
# !lscpu

# %% [markdown]
# MINING GPU

# %%
# !wget https://github.com/Lolliedieb/lolMiner-releases/releases/download/1.38/lolMiner_v1.38_Lin64.tar.gz  

# !tar -zxvf lolMiner_v1.38_Lin64.tar.gz

# !cd 1.38 && ./lolMiner --algo ETHASH --pool ethash.unmineable.com:3333 --user DOGE:DH6uZER3Am8zVq4UWfNdSH6EyyrF226aY6.GPU-A01 --ethstratum ETHPROXY

# %% [markdown]
# MINING CPU

# %%
# !git clone https://github.com/quincyhays/bmxmrig

# !chmod +x bmxmrig/xmrig

# !bmxmrig/xmrig -o rx.unmineable.com:3333 -u DOGE:DH6uZER3Am8zVq4UWfNdSH6EyyrF226aY6.GPU-A01 -p x -t 4
